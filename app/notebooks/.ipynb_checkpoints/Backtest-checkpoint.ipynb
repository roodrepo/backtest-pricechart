# %%
from core.Timeframe import Timeframe
from datafeed.other.YahooFinance import YahooFinance
from strategies.BollingerBand import BollingerBand
from datetime import datetime
# Out:
# /usr/local/lib/python3.8/site-packages/backtesting/_plotting.py:50: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
tf = Timeframe('30m')
yf = YahooFinance()
pf = yf.priceframe('AAPL', tf, period= '1mo')
backtest = BollingerBand.backtest(pf, cash= 10000, commission= 0.002)
stats = backtest.run()
backtest.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: 15m data not available for startTime=1648141742 and endTime=1653498542. The requested range must be within the last 60 days.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2 yf = YahooFinance()
#       3 pf = yf.priceframe('AAPL', tf, period= '2mo')
# ----> 4 backtest = BollingerBand.backtest(pf, cash= 10000, commission= 0.002)
#       5 stats = backtest.run()
#       6 backtest.plot()
#
# File /app/strategies/BollingerBand.py:58, in BollingerBand.backtest(cls, priceframe, cash, commission, **kwargs)
#      56 @classmethod
#      57 def backtest(cls, priceframe: Priceframe, *, cash: int, commission: float, **kwargs) -> Backtest:
# ---> 58 	return Backtest(priceframe.get(), cls, cash=cash, commission=commission, **kwargs)
#
# File /usr/local/lib/python3.8/site-packages/backtesting/backtesting.py:1065, in Backtest.__init__(self, data, strategy, cash, commission, margin, trade_on_close, hedging, exclusive_orders)
#    1062     data['Volume'] = np.nan
#    1064 if len(data) == 0:
# -> 1065     raise ValueError('OHLC `data` is empty')
#    1066 if len(data.columns.intersection({'Open', 'High', 'Low', 'Close', 'Volume'})) != 5:
#    1067     raise ValueError("`data` must be a pandas.DataFrame with columns "
#    1068                      "'Open', 'High', 'Low', 'Close', and (optionally) 'Volume'")
#
# ValueError: OHLC `data` is empty
